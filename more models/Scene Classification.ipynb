# %%
import os
# os.listdir('../input/iuuihb/')

# %%
import pandas as pd
import numpy as np

e1 = pd.read_csv('../input/ensemble-learning/E1.csv')
e2 = pd.read_csv('../input/ensemble-learning/E2.csv')
e3 = pd.read_csv('../input/ensemble-learning/E3.csv')
e4 = pd.read_csv('../input/ensemble-learning/E4.csv')
e5 = pd.read_csv('../input/ensemble-2/R1.csv')
e6 = pd.read_csv('../input/ensemble-2/R2.csv')
e7 = pd.read_csv('../input/ensemble-2/R3.csv')
e8 = pd.read_csv('../input/ensemble-2/R4.csv')
e9 = pd.read_csv('../input/ensemble-7/R5.csv')
e10 = pd.read_csv('../input/ensemble-7/R6.csv')
e11 = pd.read_csv('../input/ensemble-7/R7.csv')
e12 = pd.read_csv('../input/ensemble-10/R8.csv')
e13 = pd.read_csv('../input/ensemble/R9.csv')
e14 = pd.read_csv('../input/ensemble-11/R10.csv')
e15 = pd.read_csv('../input/m0-m1/M0.csv')
e16 = pd.read_csv('../input/m0-m1/M1.csv')
e17 = pd.read_csv('../input/ensemble-5/EnsemblePrime1 .csv')
e18 = pd.read_csv('../input/ensemble-5/EnsemblePrime2.csv')
e19 = pd.read_csv('../input/ensemble-8/Ensemble Prime Final.csv')
e20 = pd.read_csv('../input/ensemble-8/Ensemble Prime Final2.csv')
e21 = pd.read_csv('../input/ensemble-8/iscc0.csv')
e22 = pd.read_csv('../input/ensemble-9/iscc1 (1).csv')
e23 = pd.read_csv('../input/ensemble-9/iscc2.csv')
e24 = pd.read_csv('../input/ensembles/---.csv')
e25 = pd.read_csv('../input/newn2p/N2.csv')
e26 = pd.read_csv('../input/m3ensemble/M3.csv')
e27 = pd.read_csv('../input/news51/NEW5.csv')
e28 = pd.read_csv('../input/iuuihb/34.csv')
e29 = pd.read_csv('../input/dataset/R11.csv') #19-25

# %%
i = 0
l1, l2, l3, l4, l5, l6, l7, l8, l9, l10, l11, l12, l13, l14, l15, l16, l17, l18, l19, l20, l21, l22, l23, l24, l25, l26, l27, l28, l29 = [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []
while True:
    if i < 7301:
        l1.append(e1['label'][i][1:-1].split())
        l2.append(e2['label'][i][1:-1].split())
        l3.append(e3['label'][i][1:-1].split())
        l4.append(e4['label'][i][1:-1].split())
        l5.append(e5['label'][i][1:-1].split())
        l6.append(e6['label'][i][1:-1].split())
        l7.append(e7['label'][i][1:-1].split())
        l8.append(e8['label'][i][1:-1].split())
        l9.append(e9['label'][i][1:-1].split())
        l10.append(e10['label'][i][1:-1].split())
        l11.append(e11['label'][i][1:-1].split())
        l12.append(e12['label'][i][1:-1].split())
        l13.append(e13['label'][i][1:-1].split())
        l14.append(e14['label'][i][1:-1].split())
        l15.append(e15['label'][i][1:-1].split())
        l16.append(e16['label'][i][1:-1].split())
        l17.append(e17['label'][i][1:-1].split())
        l18.append(e18['label'][i][1:-1].split())
        l19.append(e19['label'][i][1:-1].split())
        l20.append(e20['label'][i][1:-1].split())
        l21.append(e21['label'][i][1:-1].split())
        l22.append(e22['label'][i][1:-1].split())
        l23.append(e23['label'][i][1:-1].split())
        l24.append(e24['label'][i][1:-1].split())
        l25.append(e25['label'][i][1:-1].split())
        l26.append(e26['label'][i][1:-1].split())
        l27.append(e27['label'][i][1:-1].split())
        l28.append(e28['label'][i][1:-1].split())
        l29.append(e29['label'][i][1:-1].split())
        i += 1
    else:
        break

# %%
label = []
for i in range(len(e1)):
    bel = []
    for j in range(6):
        bel.append((float(l1[i][j]) + float(l2[i][j]) + float(l3[i][j]) + float(l4[i][j]) + float(l5[i][j]) + float(l6[i][j]) + float(l7[i][j]) + float(l8[i][j]) + float(l9[i][j]) + float(l10[i][j]) + float(l11[i][j]) + float(l12[i][j]) + float(l13[i][j]) + float(l14[i][j]) + float(l15[i][j]) + float(l16[i][j]) + float(l17[i][j])+ float(l18[i][j]) + float(l19[i][j]) + float(l20[i][j]) + float(l21[i][j]) + float(l22[i][j]) + float(l23[i][j]) + float(l24[i][j]) + float(l25[i][j]) + float(l26[i][j]) + float(l27[i][j]) + float(l28[i][j]) + float(l29[i][j]))/29) 
        #bel.append((float(l5[i][j]) + float(l6[i][j]) + float(l7[i][j]) + float(l8[i][j]))/4) 
        #bel.append((float(l5[i][j]) + float(l6[i][j]) + float(l7[i][j]))/3) 
        #bel.append((float(l1[i][j]) + float(l2[i][j]) + float(l3[i][j]) + float(l4[i][j]) +  float(l9[i][j]) + float(l10[i][j]) + float(l11[i][j]) + float(l12[i][j]) + float(l13[i][j]) + float(l14[i][j]) + float(l15[i][j]) + float(l16[i][j]) + float(l17[i][j]) + float(l18[i][j]) + float(l19[i][j]) + float(l20[i][j]) + float(l21[i][j]) + float(l22[i][j]) + float(l23[i][j]) + float(l24[i][j]) )/20) 
        #bel.append((float(l1[i][j]) + float(l2[i][j]) + float(l3[i][j]) + float(l4[i][j]) + float(l5[i][j]) + float(l6[i][j]) + float(l7[i][j]) + float(l8[i][j]) +  float(l9[i][j]) + float(l10[i][j]) + float(l11[i][j]) + float(l12[i][j]) + float(l13[i][j]) + float(l14[i][j]) + float(l15[i][j]) + float(l16[i][j]) + float(l17[i][j]) + float(l18[i][j]) + float(l19[i][j]) + float(l20[i][j]) + float(l21[i][j]) + float(l22[i][j]) + float(l23[i][j]) + float(l24[i][j]) + float(l25[i][j]) + float(l26[i][j]) + float(l27[i][j]))/27) 
        ##This one is best bel.append(( float(l1[i][j]) + float(l2[i][j])+ float(l3[i][j]) + float(l5[i][j]) + float(l6[i][j]) + float(l7[i][j]) + float(l8[i][j]) +  float(l9[i][j]) + float(l10[i][j]) + float(l11[i][j]) + float(l12[i][j]) + float(l13[i][j]) + float(l14[i][j]) + float(l15[i][j]) + float(l16[i][j]) + float(l17[i][j]) + float(l18[i][j])   +  float(l28[i][j]) + float(l29[i][j]))/19) 
        #bel.append(( float(l1[i][j]) + float(l2[i][j]) + float(l3[i][j]) + float(l4[i][j]) + float(l15[i][j]) + float(l16[i][j]) +  float(l28[i][j]) + float(l29[i][j]))/8) 
        #bel.append((float(l1[i][j]) + float(l2[i][j]) + float(l3[i][j]) + float(l4[i][j]) + float(l5[i][j]) + float(l6[i][j]) + float(l7[i][j]) + float(l8[i][j]) +  float(l9[i][j]) + float(l10[i][j]) + float(l11[i][j]) + float(l12[i][j]) + float(l13[i][j]) + float(l14[i][j]) + float(l15[i][j]) + float(l16[i][j]) + float(l17[i][j]) + float(l18[i][j]) + float(l19[i][j]) + float(l20[i][j]) + float(l21[i][j]) + float(l22[i][j]) + float(l23[i][j]) + float(l24[i][j]) + float(l25[i][j]) + float(l26[i][j]))/26) 
        #bel.append((float(l1[i][j]) + float(l2[i][j]) + float(l3[i][j]) + float(l4[i][j]) + float(l17[i][j]) + float(l18[i][j]) + float(l19[i][j]) + float(l20[i][j]) + float(l21[i][j]) + float(l22[i][j]) + float(l23[i][j]) + float(l24[i][j]) + float(l25[i][j]) + float(l26[i][j]))/13)
        #bel.append((float(l4[i][j]) + float(l9[i][j]) + float(l10[i][j]) + float(l11[i][j]) + float(l12[i][j])  + float(l13[i][j]) + float(l18[i][j]) + float(l19[i][j]) )/8) 
    label.append(bel)

# %%
array = np.array(label)

# %%
labelled_preds = []
for pred in array:
    labelled_preds.append(int(np.argmax(pred)))

# %%
submission = pd.DataFrame(
    {'image_name': e1['image_name'],
     'label': labelled_preds,
    })
submissionPrime = pd.DataFrame(
    {'image_name': e1['image_name'],
     'label': list(array),
    })

# %%
submission.to_csv('Submission.csv')
