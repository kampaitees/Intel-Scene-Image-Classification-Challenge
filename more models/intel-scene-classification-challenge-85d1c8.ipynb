# %%
path = "../input/scene_classification/scene_classification/train/"

# %%
from fastai import *
from fastai.vision import *

# %%
bs = 64

# %%
df = pd.read_csv('../input/scene_classification/scene_classification/train.csv')
df.head()
# Out:
#   image_name  label
# 0      0.jpg      0
# 1      1.jpg      4
# 2      2.jpg      5
# 3      4.jpg      0
# 4      7.jpg      4

# %%
tfms = get_transforms(do_flip=False)
data = (ImageItemList.from_csv(path, csv_name='../train.csv') #Where to find the data? -> in path and its subfolders
        .random_split_by_pct()              #How to split in train/valid? -> use the folders
        .label_from_df()            #How to label? -> depending on the folder of the filenames
        .add_test_folder(test_folder = '../test')              #Optionally add a test set (here default name is test)
        .transform(tfms, size=128)       #Data augmentation? -> use tfms with a size of 64
        .databunch())

# %%
data.show_batch(rows=3, figsize=(8,10))

# %%
print(data.classes)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
learn = create_cnn(data, models.resnet34, metrics=[error_rate, accuracy], model_dir="/tmp/model/")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /tmp/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:01<00:00, 78556884.71it/s]

# %%
learn.fit_one_cycle(15)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='15', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       93.33% [14/15 16:13<01:09]
#     </div>
#
# <table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.648899</th>
#     <th>0.404639</th>
#     <th>0.142689</th>
#     <th>0.857311</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.426395</th>
#     <th>0.329165</th>
#     <th>0.121257</th>
#     <th>0.878743</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.373855</th>
#     <th>0.279042</th>
#     <th>0.102466</th>
#     <th>0.897534</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.320331</th>
#     <th>0.280932</th>
#     <th>0.109806</th>
#     <th>0.890194</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.313147</th>
#     <th>0.229469</th>
#     <th>0.080153</th>
#     <th>0.919847</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.255796</th>
#     <th>0.221708</th>
#     <th>0.079859</th>
#     <th>0.920141</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.251840</th>
#     <th>0.217684</th>
#     <th>0.082501</th>
#     <th>0.917499</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.232533</th>
#     <th>0.209018</th>
#     <th>0.071932</th>
#     <th>0.928068</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.213996</th>
#     <th>0.195100</th>
#     <th>0.068115</th>
#     <th>0.931885</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.197060</th>
#     <th>0.205763</th>
#     <th>0.071345</th>
#     <th>0.928655</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.183526</th>
#     <th>0.194026</th>
#     <th>0.064298</th>
#     <th>0.935702</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.179557</th>
#     <th>0.193454</th>
#     <th>0.066060</th>
#     <th>0.933940</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.161323</th>
#     <th>0.191438</th>
#     <th>0.067528</th>
#     <th>0.932472</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.161164</th>
#     <th>0.191426</th>
#     <th>0.066941</th>
#     <th>0.933059</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='171' class='' max='212', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.66% [171/212 00:48<00:11 0.1490]
#     </div>

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.most_confused(min_val=2)
# Out:
# [(2, 3, 57),
#  (3, 2, 56),
#  (5, 0, 29),
#  (0, 5, 27),
#  (2, 4, 14),
#  (3, 4, 14),
#  (4, 3, 11),
#  (1, 3, 5),
#  (4, 0, 5),
#  (0, 4, 4),
#  (2, 1, 4),
#  (4, 2, 4)]

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
# Out:
# Min numerical gradient: 5.75E-06

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 04:59 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.154144</th>
#     <th>0.193029</th>
#     <th>0.066647</th>
#     <th>0.933353</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.153745</th>
#     <th>0.190659</th>
#     <th>0.063418</th>
#     <th>0.936583</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.130738</th>
#     <th>0.190076</th>
#     <th>0.064885</th>
#     <th>0.935115</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.125029</th>
#     <th>0.186358</th>
#     <th>0.063418</th>
#     <th>0.936583</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %%
preds,_ = learn.get_preds(ds_type=DatasetType.Test)

# %%
labelled_preds = []
for pred in preds:
    labelled_preds.append(int(np.argmax(pred)))
    
# labelled_preds[0:10]
len(labelled_preds)
# Out:
# 7301

# %%
import os
filenames = os.listdir('../input/scene_classification/scene_classification/test/')

# %%
len(filenames) == len(labelled_preds)
# Out:
# True

# %%
submission = pd.DataFrame(
    {'image_name': filenames,
     'label': labelled_preds,
    })

# %%
submission.to_csv('first_submission.csv')

# %%
y_test = submission
image_name = list(submission['image_name'])
label = list(submission['label'])
for i in range(len(submission)):
    for j in range(len(submission)):
        if j+1 < len(submission) and int(image_name[j][:-4]) > int(image_name[j+1][:-4]) :
            temp = image_name[j]
            image_name[j] = image_name[j+1]
            image_name[j+1] = temp
            
            tempPrime =  label[j]
            label[j] = label[j+1]
            label[j+1] = tempPrime

# %%
y_test['image_name'] = pd.DataFrame(image_name)
y_test['label'] = pd.DataFrame(label)

# %%
y_test.to_csv('Scene3.csv')

# %%
y_test.head(10)
# Out:
#   image_name  label
# 0      3.jpg      5
# 1      5.jpg      0
# 2      6.jpg      4
# 3     11.jpg      2
# 4     14.jpg      5
# 5     22.jpg      1
# 6     25.jpg      4
# 7     28.jpg      3
# 8     30.jpg      2
# 9     38.jpg      2
